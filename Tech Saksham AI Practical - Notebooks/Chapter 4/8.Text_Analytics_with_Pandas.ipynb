# %% [markdown]
# # Text Analytics Using Pandas

# %% [markdown]
# # Code 1:

# %%
# Converting values in the name column into lower case.


# Import pandas package 
import pandas as pd 
   
# Define a dictionary containing employee data 
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 
   
# Convert the dictionary into DataFrame  
df = pd.DataFrame(data) 
   
# converting and overwriting values in column 
df["Name"]= df["Name"].str.lower()
 
print(df)
# Out:
#      Address  Age    Name Qualification
# 0      Delhi   27     jai           Msc
# 1     Kanpur   24  princi            MA
# 2  Allahabad   22  gaurav           MCA
# 3    Kannauj   32    anuj           Phd

# %% [markdown]
# # Code 2:

# %%
#Converting all values in the Team column into upper case (use  nba.csv file)


# importing pandas package 
import pandas as pd 
   
# making data frame from csv file 
data = pd.read_csv("E:/e data/EduNet Doc/Content Development/content/Practicals/CSV Files/nba.csv") 
   
# converting and overwriting values in column 
data["Team"]= data["Team"].str.upper() 
   
# display 
data
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          BOSTON CELTICS     0.0       PG  25.0
# 1                Jae Crowder          BOSTON CELTICS    99.0       SF  25.0
# 2               John Holland          BOSTON CELTICS    30.0       SG  27.0
# 3                R.J. Hunter          BOSTON CELTICS    28.0       SG  22.0
# 4              Jonas Jerebko          BOSTON CELTICS     8.0       PF  29.0
# 5               Amir Johnson          BOSTON CELTICS    90.0       PF  29.0
# 6              Jordan Mickey          BOSTON CELTICS    55.0       PF  21.0
# 7               Kelly Olynyk          BOSTON CELTICS    41.0        C  25.0
# 8               Terry Rozier          BOSTON CELTICS    12.0       PG  22.0
# 9               Marcus Smart          BOSTON CELTICS    36.0       PG  22.0
# 10           Jared Sullinger          BOSTON CELTICS     7.0        C  24.0
# ...

# %% [markdown]
# # Code 3:

# %%
# To separat Address column  at the first occurrence of “a” and not on the later occurrence by setting  n parameter equal to 1.


# importing pandas module  
import pandas as pd 
     
# Define a dictionary containing employee data 
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Knnuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 
 
# Convert the dictionary into DataFrame  
df = pd.DataFrame(data) 
    
# dropping null value columns to avoid errors 
df.dropna(inplace = True) 
    
# new data frame with split value columns 
df["Address"]= df["Address"].str.split("a", n = 1, expand = True) 
   
# df display 
print(df)
# Out:
#   Address  Age    Name Qualification
# 0       N   27     Jai           Msc
# 1       K   24  Princi            MA
# 2     All   22  Gaurav           MCA
# 3    Knnu   32    Anuj           Phd

# %% [markdown]
# # Code 4:

# %%
# Replacing all the values in Age column having age=25.0 by “Twenty five”.


# importing pandas module 
import pandas as pd
 
# reading csv file
data = pd.read_csv("E:/e data/EduNet Doc/Content Development/content/Practicals/CSV Files/nba.csv")
 
# overwriting column with replaced value of age
data["Age"]= data["Age"].replace(25.0, "Twenty five")
 
# creating a filter for age column 
# where age = "Twenty five"
filter = data["Age"]=="Twenty five"
 
# printing only filtered columns
data.where(filter).dropna()
# Out:
#                     Name                    Team  Number Position  \
# 0          Avery Bradley          Boston Celtics     0.0       PG
# 1            Jae Crowder          Boston Celtics    99.0       SF
# 7           Kelly Olynyk          Boston Celtics    41.0        C
# 26       Thomas Robinson           Brooklyn Nets    41.0       PF
# 35      Cleanthony Early         New York Knicks    11.0       SF
# 44      Derrick Williams         New York Knicks    23.0       PF
# 47         Isaiah Canaan      Philadelphia 76ers     0.0       PG
# 48      Robert Covington      Philadelphia 76ers    33.0       SF
# 59       Hollis Thompson      Philadelphia 76ers    31.0       SG
# 71         Terrence Ross         Toronto Raptors    31.0       SF
# 79             Ian Clark   Golden State Warriors    21.0       SG
# 105          C.J. Wilcox    Los Angeles Clippers    30.0       SG
# 113           Ryan Kelly      Los Angeles Lakers     4.0       PF
# ...

# %% [markdown]
# # Code 5:

# %%
# Concatenation of address with Name using separator “, “


# importing pandas module 
import pandas as pd 
   
# Define a dictionary containing employee data 
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 
 
# Convert the dictionary into DataFrame  
df = pd.DataFrame(data) 
 
# making copy of address column 
new = df["Address"].copy() 
   
# concatenating address with name column 
# overwriting name column 
df["Name"]= df["Name"].str.cat(new, sep =", ") 
   
# display 
print(df)
# Out:
#      Address  Age               Name Qualification
# 0     Nagpur   27        Jai, Nagpur           Msc
# 1     Kanpur   24     Princi, Kanpur            MA
# 2  Allahabad   22  Gaurav, Allahabad           MCA
# 3    Kannuaj   32      Anuj, Kannuaj           Phd

# %% [markdown]
# # Code 6:

# %%
# Concatenation of address with Name using separator “, “ in CSV file.


# importing pandas module
import pandas as pd
 
# importing csv file
data = pd.read_csv("E:/e data/EduNet Doc/Content Development/content/Practicals/CSV Files/nba.csv")
 
# making copy of team column
new = data["Team"].copy()
 
# concatenating team with name column
# overwriting name column
data["Name"]= data["Name"].str.cat(new, sep =", ")
 
# display
data
# Out:
#                                          Name                    Team  Number  \
# 0               Avery Bradley, Boston Celtics          Boston Celtics     0.0
# 1                 Jae Crowder, Boston Celtics          Boston Celtics    99.0
# 2                John Holland, Boston Celtics          Boston Celtics    30.0
# 3                 R.J. Hunter, Boston Celtics          Boston Celtics    28.0
# 4               Jonas Jerebko, Boston Celtics          Boston Celtics     8.0
# 5                Amir Johnson, Boston Celtics          Boston Celtics    90.0
# 6               Jordan Mickey, Boston Celtics          Boston Celtics    55.0
# 7                Kelly Olynyk, Boston Celtics          Boston Celtics    41.0
# 8                Terry Rozier, Boston Celtics          Boston Celtics    12.0
# 9                Marcus Smart, Boston Celtics          Boston Celtics    36.0
# 10            Jared Sullinger, Boston Celtics          Boston Celtics     7.0
# ...

# %% [markdown]
# # Code 7:

# %%
# Comparison Using CSV File


# importing pandas module 
import pandas as pd 
   
# making data frame 
data = pd.read_csv("E:/e data/EduNet Doc/Content Development/content/Practicals/CSV Files/nba.csv") 
   
# replacing team name and adding spaces in start and end 
new = data["Team"].replace("Boston Celtics", "  Boston Celtics  ").copy() 
   
# checking with custom removed space string 
new.str.lstrip()=="Boston Celtics  "
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 428    False
# 429    False
# 430    False
# 431    False
# 432    False
# 433    False
# 434    False
# 435    False
# 436    False
# 437    False
# 438    False
# 439    False
# 440    False
# 441    False
# 442    False
# 443    False
# 444    False
# 445    False
# 446    False
# 447    False
# 448    False
# 449    False
# 450    False
# 451    False
# 452    False
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Name: Team, Length: 458, dtype: bool

# %% [markdown]
# # Code 8:

# %%
 # Handling NULL values
# Selecting the data frame  which have “e” in the end of the string in College column.
# NaN values are not displayed since the na parameter was set to False.


# importing pandas module
import pandas as pd

# reading csv file 
data = pd.read_csv("E:/e data/EduNet Doc/Content Development/content/Practicals/CSV Files/nba.csv")

# String to be searched in end of string
search ="e"

# boolean series returned with False at place of NaN
bool_series = data["College"].str.lower().str.endswith(search, na = False)

# displaying filtered dataframe
data[bool_series]
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 1         Jae Crowder          Boston Celtics    99.0       SF  25.0    6-6
# 3         R.J. Hunter          Boston Celtics    28.0       SG  22.0    6-5
# 8        Terry Rozier          Boston Celtics    12.0       PG  22.0    6-2
# 9        Marcus Smart          Boston Celtics    36.0       PG  22.0    6-4
# 10    Jared Sullinger          Boston Celtics     7.0        C  24.0    6-9
# 12        Evan Turner          Boston Celtics    11.0       SG  27.0    6-7
# 16       Markel Brown           Brooklyn Nets    22.0       SG  24.0    6-3
# 24   Chris McCullough           Brooklyn Nets     1.0       PF  21.0   6-11
# 33    Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 35   Cleanthony Early         New York Knicks    11.0       SF  25.0    6-8
# 37       Jerian Grant         New York Knicks    13.0       PG  23.0    6-4
# ...

# %% [markdown]
# # Code 9:

# %%
# Return the length of each string in name column.


# importing pandas module
import pandas as pd

# reading csv file
data = pd.read_csv("E:/e data/EduNet Doc/Content Development/content/Practicals/CSV Files/nba.csv")

# dropping null value columns to avoid errors
data.dropna(inplace = True)

# creating new column for len
# passing values through str.len()
data["Name Length"]= data["Name"].str.len()

# display
data
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 13               James Young          Boston Celtics    13.0       SG  20.0
# ...

# %% [markdown]
# # Code 10:

# %%
# Searching substring (More than one character)
# ‘er’ substring will be searched in the Name column of data frame. 
#The start parameter is kept 2 to start search from 3rd (index position 2) element.


# importing pandas module
import pandas as pd

# reading csv file
data = pd.read_csv("E:/e data/EduNet Doc/Content Development/content/Practicals/CSV Files/nba.csv")

# dropping null value columns to avoid errors
data.dropna(inplace = True)


# substring to be searched
sub ='er'

# start var
start = 2

# creating and passsing series to new column
data["Indexes"]= data["Name"].str.find(sub, start)

# display
data
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 13               James Young          Boston Celtics    13.0       SG  20.0
# ...
