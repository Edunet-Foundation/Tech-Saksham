# %% [markdown]
# # Creating neural network from scratch with python

# %%
#Importing the dataset 

import csv
import pandas as pd

# add header names
headers =  ['age', 'sex','chest_pain','resting_blood_pressure',  
        'serum_cholestoral', 'fasting_blood_sugar', 'resting_ecg_results',
        'max_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak',"slope of the peak",
        'num_of_major_vessels','thal', 'heart_disease']

heart_df = pd.read_csv('heart.dat', sep=' ', names=headers)
heart_df.head()
# Out:
#     age  sex  chest_pain  ...  num_of_major_vessels  thal  heart_disease
# 0  70.0  1.0         4.0  ...                   3.0   3.0              2
# 1  67.0  0.0         3.0  ...                   0.0   7.0              1
# 2  57.0  1.0         2.0  ...                   0.0   7.0              2
# 3  64.0  1.0         4.0  ...                   1.0   7.0              1
# 4  74.0  0.0         2.0  ...                   1.0   3.0              1
#
# [5 rows x 14 columns]

# %%
#Getting shape of the data
heart_df.shape
# Out:
# (270, 14)

# %%
#Looking for the null values through the dataset because neural net require non null variables
heart_df.isna().sum()
# Out:
# age                        0
# sex                        0
# chest_pain                 0
# resting_blood_pressure     0
# serum_cholestoral          0
# fasting_blood_sugar        0
# resting_ecg_results        0
# max_heart_rate_achieved    0
# exercise_induced_angina    0
# oldpeak                    0
# slope of the peak          0
# num_of_major_vessels       0
# thal                       0
# heart_disease              0
# dtype: int64

# %%
#Splitting the dataset into training and test parts
import numpy as np
import warnings
warnings.filterwarnings("ignore") #suppress warnings
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

#convert imput to numpy arrays
X = heart_df.drop(columns=['heart_disease'])

#replace target class with 0 and 1 
#1 means "have heart disease" and 0 means "do not have heart disease"
heart_df['heart_disease'] = heart_df['heart_disease'].replace(1, 0)
heart_df['heart_disease'] = heart_df['heart_disease'].replace(2, 1)

y_label = heart_df['heart_disease'].values.reshape(X.shape[0], 1)

#split data into train and test set
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y_label, test_size=0.2, random_state=2)

#standardize the dataset
sc = StandardScaler()
sc.fit(Xtrain)
Xtrain = sc.transform(Xtrain)
Xtest = sc.transform(Xtest)

print(f"Shape of train set is {Xtrain.shape}")
print(f"Shape of test set is {Xtest.shape}")
print(f"Shape of train label is {ytrain.shape}")
print(f"Shape of test labels is {ytest.shape}")
# Out:
# Shape of train set is (216, 13)
# Shape of test set is (54, 13)
# Shape of train label is (216, 1)
# Shape of test labels is (54, 1)

# %%
#Implementing Neural network class

class NeuralNet():
    '''
    A two layer neural network
    '''
        
    def __init__(self, layers=[13,8,1], learning_rate=0.001, iterations=100):
        self.params = {}
        self.learning_rate = learning_rate
        self.iterations = iterations
        self.loss = []
        self.sample_size = None
        self.layers = layers
        self.X = None
        self.y = None
                
    def init_weights(self):
        '''
        Initialize the weights from a random normal distribution
        '''
        np.random.seed(1) # Seed the random number generator
        self.params["W1"] = np.random.randn(self.layers[0], self.layers[1]) 
        self.params['b1']  =np.random.randn(self.layers[1],)
        self.params['W2'] = np.random.randn(self.layers[1],self.layers[2]) 
        self.params['b2'] = np.random.randn(self.layers[2],)
        
    def relu(self,Z):
        '''
        The ReLu activation function is to performs a threshold
        operation to each input element where values less 
        than zero are set to zero.
        '''
        return np.maximum(0,Z)
    
    def sigmoid(self,Z):
        '''
        The sigmoid function takes in real numbers in any range and 
        squashes it to a real-valued output between 0 and 1.
        '''
        return 1.0/(1.0+np.exp(-Z))
    
    def entropy_loss(self,y, yhat):
        nsample = len(y)
        loss = -1/nsample * (np.sum(np.multiply(np.log(yhat), y) + np.multiply((1 - y), np.log(1 - yhat))))
        return loss
    
    def forward_propagation(self):
        '''
        Performs the forward propagation
        '''
        
        Z1 = self.X.dot(self.params['W1']) + self.params['b1']
        A1 = self.relu(Z1)
        Z2 = A1.dot(self.params['W2']) + self.params['b2']
        yhat = self.sigmoid(Z2)
        loss = self.entropy_loss(self.y,yhat)

        # save calculated parameters     
        self.params['Z1'] = Z1
        self.params['Z2'] = Z2
        self.params['A1'] = A1

        return yhat,loss
    
    def back_propagation(self,yhat):
        '''
        Computes the derivatives and update weights and bias according.
        '''
        def dRelu(x):
            x[x<=0] = 0
            x[x>0] = 1
            return x
        
        dl_wrt_yhat = -(np.divide(self.y,yhat) - np.divide((1 - self.y),(1-yhat)))
        dl_wrt_sig = yhat * (1-yhat)
        dl_wrt_z2 = dl_wrt_yhat * dl_wrt_sig

        dl_wrt_A1 = dl_wrt_z2.dot(self.params['W2'].T)
        dl_wrt_w2 = self.params['A1'].T.dot(dl_wrt_z2)
        dl_wrt_b2 = np.sum(dl_wrt_z2, axis=0)

        dl_wrt_z1 = dl_wrt_A1 * dRelu(self.params['Z1'])
        dl_wrt_w1 = self.X.T.dot(dl_wrt_z1)
        dl_wrt_b1 = np.sum(dl_wrt_z1, axis=0)
        
        #update the weights and bias
        self.params['W1'] = self.params['W1'] - self.learning_rate * dl_wrt_w1
        self.params['W2'] = self.params['W2'] - self.learning_rate * dl_wrt_w2
        self.params['b1'] = self.params['b1'] - self.learning_rate * dl_wrt_b1
        self.params['b2'] = self.params['b2'] - self.learning_rate * dl_wrt_b2
        
    
    def fit(self, X, y):
        '''
        Trains the neural network using the specified data and labels
        '''
        self.X = X
        self.y = y
        self.init_weights() #initialize weights and bias


        for i in range(self.iterations):
            yhat, loss = self.forward_propagation()
            self.back_propagation(yhat)
            self.loss.append(loss)
            
    def predict(self, X):
        '''
        Predicts on a test data
        '''
        Z1 = X.dot(self.params['W1']) + self.params['b1']
        A1 = self.relu(Z1)
        Z2 = A1.dot(self.params['W2']) + self.params['b2']
        pred = self.sigmoid(Z2)
        return np.round(pred) 
        
    
    def acc(self, y, yhat):
        '''
        Calculates the accutacy between the predicted valuea and the truth labels
        '''
        acc = int(sum(y == yhat) / len(y) * 100)
        return acc


    def plot_loss(self):
        '''
        Plots the loss curve
        '''
        plt.plot(self.loss)
        plt.xlabel("Iteration")
        plt.ylabel("logloss")
        plt.title("Loss curve for training")
        plt.show()

# %%
nn = NeuralNet() # create the NN model
nn.fit(Xtrain, ytrain) #train the model

# %%
nn.plot_loss()

# %%
train_pred = nn.predict(Xtrain)
test_pred = nn.predict(Xtest)

print("Train accuracy is {}".format(nn.acc(ytrain, train_pred)))
print("Test accuracy is {}".format(nn.acc(ytest, test_pred)))
# Out:
# Train accuracy is 87
# Test accuracy is 75

# %%
nn_1 = NeuralNet(layers=[13,10,1], learning_rate=0.001, iterations=300) # create the NN model
nn_1.fit(Xtrain, ytrain) #train the model
nn_1.plot_loss()

# %%
train_pred = nn_1.predict(Xtrain)
test_pred = nn_1.predict(Xtest)
# print(Xtrain)
# print(Xtest)
# print(train_pred)
# print(test_pred)
print("Train accuracy is {}".format(nn_1.acc(ytrain, train_pred)))
print("Test accuracy is {}".format(nn_1.acc(ytest, test_pred)))
# Out:
# Train accuracy is 91
# Test accuracy is 77

# %%
#Creating neural net with python libraries

# %%
#With scikit learn - with multilayer perceptron classifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

sknet = MLPClassifier(hidden_layer_sizes=(8), learning_rate_init=0.001, max_iter=100)

# %%
sknet.fit(Xtrain, ytrain)
preds_train = sknet.predict(Xtrain)
preds_test = sknet.predict(Xtest)

print("Train accuracy of sklearn neural network: {}".format(round(accuracy_score(preds_train, ytrain),2)*100))
print("Test accuracy of sklearn neural network: {}".format(round(accuracy_score(preds_test, ytest),2)*100))
# Out:
# Train accuracy of sklearn neural network: 85.0
# Test accuracy of sklearn neural network: 69.0

# %%
#With Keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# define the model
model = Sequential()
model.add(Dense(8, input_shape=(13,)))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the model
opt = Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(Xtrain, ytrain, epochs=100, verbose=1)
train_acc = model.evaluate(Xtrain, ytrain, verbose=1)[1]
# print(train_acc)
test_acc = model.evaluate(Xtest, ytest, verbose=1)[1]
# print(test_acc)
print("Train accuracy of keras neural network: {}".format(round((train_acc * 100), 2)))
print("Test accuracy of keras neural network: {}".format(round((test_acc * 100),2)))
# Out:
# Epoch 1/100
# 7/7 [==============================] - 3s 3ms/step - loss: 0.5331 - accuracy: 0.7559
# Epoch 2/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4797 - accuracy: 0.8069
# Epoch 3/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4858 - accuracy: 0.7629
# Epoch 4/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3914 - accuracy: 0.8321
# Epoch 5/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4351 - accuracy: 0.7902
# Epoch 6/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3949 - accuracy: 0.8165
# Epoch 7/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4065 - accuracy: 0.8172
# Epoch 8/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4161 - accuracy: 0.8189
# Epoch 9/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4051 - accuracy: 0.8150
# Epoch 10/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3609 - accuracy: 0.8194
# Epoch 11/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3816 - accuracy: 0.8270
# Epoch 12/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3647 - accuracy: 0.8378
# Epoch 13/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3634 - accuracy: 0.8442
# Epoch 14/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3679 - accuracy: 0.8254
# Epoch 15/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3534 - accuracy: 0.8557
# Epoch 16/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3448 - accuracy: 0.8621
# Epoch 17/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3455 - accuracy: 0.8616
# Epoch 18/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3343 - accuracy: 0.8727
# Epoch 19/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3461 - accuracy: 0.8548
# Epoch 20/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3736 - accuracy: 0.8377
# Epoch 21/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3242 - accuracy: 0.8595
# Epoch 22/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3194 - accuracy: 0.8758
# Epoch 23/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3569 - accuracy: 0.8356
# Epoch 24/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3458 - accuracy: 0.8383
# Epoch 25/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3830 - accuracy: 0.8175
# Epoch 26/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2979 - accuracy: 0.8555
# Epoch 27/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3455 - accuracy: 0.8318
# Epoch 28/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3517 - accuracy: 0.8457
# Epoch 29/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3242 - accuracy: 0.8660
# Epoch 30/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3068 - accuracy: 0.8690
# Epoch 31/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3246 - accuracy: 0.8527
# Epoch 32/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3135 - accuracy: 0.8656
# Epoch 33/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2978 - accuracy: 0.8621
# Epoch 34/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3049 - accuracy: 0.8793
# Epoch 35/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3412 - accuracy: 0.8392
# Epoch 36/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3597 - accuracy: 0.8364
# Epoch 37/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3000 - accuracy: 0.8829
# Epoch 38/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3029 - accuracy: 0.8582
# Epoch 39/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3481 - accuracy: 0.8396
# Epoch 40/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2865 - accuracy: 0.8815
# Epoch 41/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3356 - accuracy: 0.8504
# Epoch 42/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2473 - accuracy: 0.8987
# Epoch 43/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3307 - accuracy: 0.8591
# Epoch 44/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3331 - accuracy: 0.8536
# Epoch 45/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3114 - accuracy: 0.8700
# Epoch 46/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2736 - accuracy: 0.8911
# Epoch 47/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3331 - accuracy: 0.8663
# Epoch 48/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2741 - accuracy: 0.8947
# Epoch 49/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3025 - accuracy: 0.8732
# Epoch 50/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2815 - accuracy: 0.8768
# Epoch 51/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3003 - accuracy: 0.8697
# Epoch 52/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3324 - accuracy: 0.8508
# Epoch 53/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3106 - accuracy: 0.8605
# Epoch 54/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3195 - accuracy: 0.8581
# Epoch 55/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2557 - accuracy: 0.9023
# Epoch 56/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3119 - accuracy: 0.8617
# Epoch 57/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2935 - accuracy: 0.8788
# Epoch 58/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2737 - accuracy: 0.8806
# Epoch 59/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3156 - accuracy: 0.8717
# Epoch 60/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2757 - accuracy: 0.8792
# Epoch 61/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3091 - accuracy: 0.8599
# Epoch 62/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2745 - accuracy: 0.8781
# Epoch 63/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2725 - accuracy: 0.8870
# Epoch 64/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2834 - accuracy: 0.8762
# Epoch 65/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2607 - accuracy: 0.8921
# Epoch 66/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2570 - accuracy: 0.8956
# Epoch 67/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2803 - accuracy: 0.8788
# Epoch 68/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2804 - accuracy: 0.8768
# Epoch 69/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2888 - accuracy: 0.8712
# Epoch 70/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2848 - accuracy: 0.8656
# Epoch 71/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2725 - accuracy: 0.8759
# Epoch 72/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2945 - accuracy: 0.8548
# Epoch 73/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3021 - accuracy: 0.8708
# Epoch 74/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2752 - accuracy: 0.8894
# Epoch 75/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2902 - accuracy: 0.8689
# Epoch 76/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2940 - accuracy: 0.8695
# Epoch 77/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.8868
# Epoch 78/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2787 - accuracy: 0.8712
# Epoch 79/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2728 - accuracy: 0.8686
# Epoch 80/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2991 - accuracy: 0.8492
# Epoch 81/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2678 - accuracy: 0.8868
# Epoch 82/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3211 - accuracy: 0.8565
# Epoch 83/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2534 - accuracy: 0.8848
# Epoch 84/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2843 - accuracy: 0.8731
# Epoch 85/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2844 - accuracy: 0.8714
# Epoch 86/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2720 - accuracy: 0.8678
# Epoch 87/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2760 - accuracy: 0.8737
# Epoch 88/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2565 - accuracy: 0.8836
# Epoch 89/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2630 - accuracy: 0.8854
# Epoch 90/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2892 - accuracy: 0.8772
# Epoch 91/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2995 - accuracy: 0.8604
# Epoch 92/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2885 - accuracy: 0.8689
# Epoch 93/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2877 - accuracy: 0.8682
# Epoch 94/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2772 - accuracy: 0.8727
# Epoch 95/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2752 - accuracy: 0.8786
# Epoch 96/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3219 - accuracy: 0.8723
# Epoch 97/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3038 - accuracy: 0.8656
# Epoch 98/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2746 - accuracy: 0.8869
# Epoch 99/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2701 - accuracy: 0.9006
# Epoch 100/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2677 - accuracy: 0.8841
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2841 - accuracy: 0.8750
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5814 - accuracy: 0.7593
# Train accuracy of keras neural network: 87.5
# Test accuracy of keras neural network: 75.93

# %%
#How to save Keras models
#save model and architecture to single file
model.save("model_9.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
#How to load saved keras model and use it again
from numpy import loadtxt
from tensorflow.keras.models import load_model
 
# load model
model = load_model("model_9.h5")
# summarize model.
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8)                 112
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________
